# %% [markdown]
# # INFO 2950 Final Project

# %%
import pandas as pd
import seaborn

# %%
# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %% [markdown]
# reserach question:

# %%
table1 = pd.read_csv('./Data_2019/Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2019.csv')

table4 = pd.read_csv('./Data_2019/Offenses_Offense_Type_by_Bias_Motivation_2019 v2.csv')

table1
# Out:
#                                       Bias_motivation Incidents Offenses  \
# 0                                               Total     7,314    8,559
# 1                               Single-Bias Incidents     7,103    8,302
# 2                            Race/Ethnicity/Ancestry:     3,963    4,784
# 3                                          Anti-White       666      755
# 4                      Anti-Black or African American     1,930    2,314
# 5               Anti-American Indian or Alaska Native       119      126
# 6                                          Anti-Asian       158      205
# 7      Anti-Native Hawaiian or Other Pacific Islander        21       25
# 8                          Anti-Multiple Races, Group       134      171
# 9                                           Anti-Arab        95      122
# 10                            Anti-Hispanic or Latino       527      676
# 11                 Anti-Other Race/Ethnicity/Ancestry       313      390
# ...

# %%
# %sql table14 << SELECT * FROM table1 FULL OUTER JOIN table4 ON table1.Offenses = table4.Total_Offenses

table14 = table14.loc[:,~table14.columns.duplicated()].copy()
table14 = table14.drop(['Total_offenses'],axis=1)
table14
# Out:
# Returning data to local variable table14
#                                       Bias_motivation Incidents Offenses  \
# 0                                               Total     7,314    8,559
# 1                               Single-Bias Incidents     7,103    8,302
# 2                            Race/Ethnicity/Ancestry:     3,963    4,784
# 3                                          Anti-White       666      755
# 4                      Anti-Black or African American     1,930    2,314
# 5               Anti-American Indian or Alaska Native       119      126
# 6                                          Anti-Asian       158      205
# 7      Anti-Native Hawaiian or Other Pacific Islander        21       25
# 8                          Anti-Multiple Races, Group       134      171
# 9                                           Anti-Arab        95      122
# 10                            Anti-Hispanic or Latino       527      676
# ...
