# %% [markdown]
# # INFO 2950 Final Project

# %%
import pandas as pd
import seaborn

# %%
# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Reserach Question: Explore the change in the distribution of biased motivation of hate crime from 2016-2020, and the effect of Covid in between.

# %%
# Import 2019 Table 1
table1_19 = pd.read_csv('./Data_2019/CSV_files_2019/Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2019.csv', thousands=',')
table1_19.head()
# Out:
#                   Bias_motivation  Incidents  Offenses  Victims1  \
# 0                           Total       7314      8559      8812
# 1           Single-Bias Incidents       7103      8302      8552
# 2        Race/Ethnicity/Ancestry:       3963      4784      4930
# 3                      Anti-White        666       755       775
# 4  Anti-Black or African American       1930      2314      2391
#
#    Known_offenders2
# 0              6406
# 1              6268
# 2              3550
# 3               645
# 4              1682

# %%
# Import 2019 Table 4
table4_19 = pd.read_csv('./Data_2019/CSV_files_2019/Offenses_Offense_Type_by_Bias_Motivation_2019 v2.csv', thousands=',')
table4_19.head()
# Out:
#                   Bias_motivation  Total_offenses  \
# 0                           Total            8559
# 1           Single-Bias Incidents            8302
# 2        Race/Ethnicity/Ancestry:            4784
# 3                      Anti-White             755
# 4  Anti-Black or African American            2314
#
#    Murder_and_nonnegligent_manslaughter  Rape  Aggravated_assault  \
# 0                                    51    30                1158
# 1                                    51    30                1139
# 2                                    31    12                 726
# 3                                     0     6                 108
# 4                                     1     2                 344
#
#    Simple_assault  Intimidation  Human_Trafficking,_Commercial_Sex_Acts  \
# 0            2023          2206                                       3
# 1            1976          2134                                       3
# 2            1225          1385                                       0
# 3             240           143                                       0
# 4             546           797                                       0
#
#    Other_crimes_against_persons  Robbery  Burglary  Larceny_theft  \
# 0                            41      125       114            284
# 1                            41      125       109            282
# 2                            13       62        46            149
# 3                             3       16        10             56
# 4                             8       13        17             19
#
#    Motor_vehicle_theft  Arson  Destruction_damage_vandalism  \
# 0                   19     60                          2152
# 1                   19     55                          2050
# 2                   13     16                           901
# 3                    4      1                            72
# 4                    3      9                           516
#
#    Other_crimes_against_properties  Crimes_against_society
# 0                               57                     236
# 1                               57                     231
# 2                               35                     170
# 3                               15                      81
# 4                                5                      34

# %%
# %sql offense_type << SELECT * FROM table1_19 FULL OUTER JOIN table4_19 ON table1_19.Offenses = table4_19.Total_Offenses

offense_type = offense_type.loc[:,~offense_type.columns.duplicated()]
offense_type = offense_type.drop(['Total_offenses'],axis=1)
offense_type.head()
# Out:
# Returning data to local variable offense_type
#                   Bias_motivation  Incidents  Offenses  Victims1  \
# 0                           Total       7314      8559      8812
# 1           Single-Bias Incidents       7103      8302      8552
# 2        Race/Ethnicity/Ancestry:       3963      4784      4930
# 3                      Anti-White        666       755       775
# 4  Anti-Black or African American       1930      2314      2391
#
#    Known_offenders2  Murder_and_nonnegligent_manslaughter  Rape  \
# 0              6406                                    51    30
# 1              6268                                    51    30
# 2              3550                                    31    12
# 3               645                                     0     6
# 4              1682                                     1     2
#
#    Aggravated_assault  Simple_assault  Intimidation  \
# 0                1158            2023          2206
# 1                1139            1976          2134
# 2                 726            1225          1385
# 3                 108             240           143
# 4                 344             546           797
#
#    Human_Trafficking,_Commercial_Sex_Acts  Other_crimes_against_persons  \
# 0                                       3                            41
# 1                                       3                            41
# 2                                       0                            13
# 3                                       0                             3
# 4                                       0                             8
#
#    Robbery  Burglary  Larceny_theft  Motor_vehicle_theft  Arson  \
# 0      125       114            284                   19     60
# 1      125       109            282                   19     55
# 2       62        46            149                   13     16
# 3       16        10             56                    4      1
# 4       13        17             19                    3      9
#
#    Destruction_damage_vandalism  Other_crimes_against_properties  \
# 0                          2152                               57
# 1                          2050                               57
# 2                           901                               35
# 3                            72                               15
# 4                           516                                5
#
#    Crimes_against_society
# 0                     236
# 1                     231
# 2                     170
# 3                      81
# 4                      34

# %%
import matplotlib.pyplot as plt
import seaborn as sns

t4_19 = table4_19.drop(['Bias_motivation', 'Total_offenses'],axis=1)
sns.barplot(data=t4_19, orient = 'h')
# Out:
# <AxesSubplot:>

# %%
import math
t4_19 = table4_19.drop(['Bias_motivation', 'Total_offenses'],axis=1)

data = t4_19.iloc[0,:].to_numpy().tolist()
labels = t4_19.columns.to_list()
colors = sns.color_palette('pastel')[0:15]
fig, ax = plt.subplots()

# plt.pie(data, labels = labels, colors = colors, autopct='%.1f%%')
l = ax.pie(data, autopct='%.1f%%', startangle=-90)

for label, t in zip(labels, l[1]):
    x, y = t.get_position()
    angle = int(math.degrees(math.atan2(y, x)))
    ha = "left"

    if x<0:
        angle -= 180
        ha = "right"

    plt.annotate(label, xy=(x,y), rotation=angle, ha=ha, va="center", rotation_mode="anchor", size=8)

plt.show()

# %%
# Import 2016 Table 4
table4_16 = pd.read_csv('./Data_2016/CSV_files_2016/Table_4_Offenses_Offense_Type_by_Bias_Motivation_2016 revised.csv', thousands=',')
table4_16.head()
# Out:
#                   Bias_motivation  Total_offenses  \
# 0                           Total            7321
# 1           Single-Bias Incidents            7227
# 2        Race/Ethnicity/Ancestry:            4229
# 3                      Anti-White             876
# 4  Anti-Black or African American            2122
#
#    Murder_and_nonnegligent_manslaughter  Rape  Aggravated_assault  \
# 0                                     9    24                 873
# 1                                     9    23                 866
# 2                                     7    10                 548
# 3                                     5     5                 120
# 4                                     2     2                 273
#
#    Simple_assault  Intimidation  Other_crime_against_persons  Robbery  \
# 0            1687          2109                           18      134
# 1            1677          2074                           17      131
# 2            1002          1320                            5       71
# 3             241           188                            2       30
# 4             455           782                            2       14
#
#    Burglary  Larceny_theft  Motor_vehicle_theft  Arson  \
# 0       123            231                   20     39
# 1       122            227                   20     38
# 2        75            149                   14     13
# 3        22             78                    6      2
# 4        17             14                    2      7
#
#    Destruction_damage_vandalism  Other_crimes_against_property  \
# 0                          1913                             59
# 1                          1882                             59
# 2                           916                             46
# 3                           122                             24
# 4                           537                              5
#
#    Crime_against_societies
# 0                       82
# 1                       82
# 2                       53
# 3                       31
# 4                       10

# %%
# Import 2017 Table 4
table4_17 = pd.read_csv('./Data_2017/CSV_files_2017/Table_4_Offenses_Offense_Type_by_Bias_Motivation_2017 revised.csv', thousands=',')
table4_17.head()
# Out:
#                   Bias_motivation  Total_offenses  \
# 0                           Total            8437
# 1           Single-Bias Incidents            8126
# 2        Race/Ethnicity/Ancestry:            4832
# 3                      Anti-White             844
# 4  Anti-Black or African American            2358
#
#    Murder_and_nonnegligent_manslaughter  Rape  Aggravated_assault  \
# 0                                    15    23                 990
# 1                                    15    23                 975
# 2                                    11     8                 638
# 3                                     5     2                 105
# 4                                     5     1                 326
#
#    Simple_assault  Intimidation  Human_Trafficking,_Commercial_Sex_Acts  \
# 0            1745          2283                                       1
# 1            1623          2156                                       1
# 2             965          1442                                       1
# 3             203           171                                       0
# 4             454           820                                       0
#
#    Other_crime_against_persons  Robbery  Burglary  Larceny_theft  \
# 0                           27      157       145            326
# 1                           27      157       140            323
# 2                           15       84        83            208
# 3                            7       22        24             92
# 4                            2       19        29             17
#
#    Motor_vehicle_theft  Arson  Destruction_damage_vandalism  \
# 0                   41     42                          2325
# 1                   41     41                          2291
# 2                   35     24                          1111
# 3                   14      3                           113
# 4                    2     15                           640
#
#    Other_crimes_against_property  Crimes_against_society
# 0                             79                     238
# 1                             79                     234
# 2                             40                     167
# 3                             20                      63
# 4                              6                      22

# %%
# Import 2018 Table 4
table4_18 = pd.read_csv('./Data_2018/CSV_files_2018/Table_4_Offenses_Offense_Type_by_Bias_Motivation_2018 revised.csv', thousands=',')
table4_18.head()
# Out:
#                   Bias_motivation  Total_offenses  \
# 0                           Total            8496
# 1           Single-Bias Incidents            8327
# 2        Race/Ethnicity/Ancestry:            4954
# 3                      Anti-White            1001
# 4  Anti-Black or African American            2325
#
#    Murder_and_nonnegligent_manslaughter  Rape  Aggravated_assault  \
# 0                                    24    22                1026
# 1                                    24    22                1017
# 2                                     8     9                 659
# 3                                     3     6                 114
# 4                                     4     2                 323
#
#    Simple_assault  Intimidation  Other_crime_against_persons  Robbery  \
# 0          1895.0          2560                           39      132
# 1          1882.0          2468                           39      131
# 2          1121.0          1627                           21       68
# 3           250.0           289                            9       15
# 4           486.0           908                            2       14
#
#    Burglary  Larceny_theft  Motor_vehicle_theft  Arson  \
# 0       131            330                   42     43
# 1       129            325                   42     43
# 2        76            195                   26     16
# 3        24             79                    8      1
# 4        24             22                    3     10
#
#    Destruction_damage_vandalism  Other_crimes_against_property  \
# 0                          1876                             87
# 1                          1830                             86
# 2                           854                             50
# 3                            91                             20
# 4                           474                              3
#
#    Crime_against_societies
# 0                      289
# 1                      289
# 2                      224
# 3                       92
# 4                       50

# %%
# Simplify Table 4

# %sql table4_16_type << SELECT Bias_motivation, Total_offenses AS Total_offenses_16 FROM table4_16 WHERE Bias_motivation IN('Race/Ethnicity/Ancestry:', 'Religion:', 'Sexual Orientation:', 'Disability:', 'Gender:', 'Gender Identity:', 'Multiple-Bias Incidents')

# %sql table4_17_type << SELECT Bias_motivation, Total_offenses AS Total_offenses_17 FROM table4_17 WHERE Bias_motivation IN('Race/Ethnicity/Ancestry:', 'Religion:', 'Sexual Orientation:', 'Disability:', 'Gender:', 'Gender Identity:', 'Multiple-Bias Incidents')

# %sql table4_18_type << SELECT Bias_motivation, Total_offenses AS Total_offenses_18 FROM table4_18 WHERE Bias_motivation IN('Race/Ethnicity/Ancestry:', 'Religion:', 'Sexual Orientation:', 'Disability:', 'Gender:', 'Gender Identity:', 'Multiple-Bias Incidents')

# %sql table4_19_type << SELECT Bias_motivation, Total_offenses AS Total_offenses_19 FROM table4_19 WHERE Bias_motivation IN('Race/Ethnicity/Ancestry:', 'Religion:', 'Sexual Orientation:', 'Disability:', 'Gender:', 'Gender Identity:', 'Multiple-Bias Incidents')
# Out:
# Returning data to local variable table4_16_type
# Returning data to local variable table4_17_type
# Returning data to local variable table4_18_type
# Returning data to local variable table4_19_type

# %%
# Combine Table 4 from 2016-2019
combined_table4 = pd.concat([table4_16_type, table4_17_type, table4_18_type, table4_19_type], axis=1)
combined_table4 = combined_table4.loc[:,~combined_table4.columns.duplicated()].copy()

combined_table4 = combined_table4.T
fheader = combined_table4.iloc[0]
combined_table4 = combined_table4[1:]
combined_table4.columns = fheader
display(combined_table4)

combined_table4.plot()
# Out:
# Bias_motivation   Race/Ethnicity/Ancestry: Religion: Sexual Orientation:  \
# Total_offenses_16                     4229      1538                1218
# Total_offenses_17                     4832      1679                1303
# Total_offenses_18                     4954      1550                1404
# Total_offenses_19                     4784      1650                1395
#
# Bias_motivation   Disability: Gender: Gender Identity: Multiple-Bias Incidents
# Total_offenses_16          76      36              130                      94
# Total_offenses_17         128      53              131                     311
# Total_offenses_18         177      58              184                     169
# Total_offenses_19         169      80              224                     257
# <AxesSubplot:>
